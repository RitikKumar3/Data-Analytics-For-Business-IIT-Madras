# %% [markdown]
# # Time Series Analysis

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("AirPassengers.csv")

# %%
data.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
data.tail()
# Out:
#        Month  #Passengers
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432

# %%
data.shape
# Out:
# (144, 2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
data['Month']=pd.to_datetime(data['Month'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    datetime64[ns]
#  1   #Passengers  144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %%
data.head()
# Out:
#        Month  #Passengers
# 0 1949-01-01          112
# 1 1949-02-01          118
# 2 1949-03-01          132
# 3 1949-04-01          129
# 4 1949-05-01          121

# %%
data.index
# Out:
# RangeIndex(start=0, stop=144, step=1)

# %%
data.index=data['Month']

# %%
data.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %%
data.head()
# Out:
#                 Month  #Passengers
# Month
# 1949-01-01 1949-01-01          112
# 1949-02-01 1949-02-01          118
# 1949-03-01 1949-03-01          132
# 1949-04-01 1949-04-01          129
# 1949-05-01 1949-05-01          121

# %%
del data['Month']

# %%
data.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
data.shape
# Out:
# (144, 1)

# %%
data.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
result=adfuller(data['#Passengers'])
pval=result[1]

# %%
# null = data is stationary
# altv = not stationary
# pval<0.05 ---> accept null hypo

# %%
pval
# Out:
# 0.991880243437641

# %%
result
# Out:
# (0.8153688792060482,
#  0.991880243437641,
#  13,
#  130,
#  {'1%': -3.4816817173418295,
#   '5%': -2.8840418343195267,
#   '10%': -2.578770059171598},
#  996.692930839019)

# %%
rolling_mean=data.rolling(window=12).mean()

# %%
rolling_mean_detrended=data-rolling_mean

# to remove the trend

# %%
ax1=plt.subplot(1,2,2)
rolling_mean_detrended.plot(figsize=(12,4),color="tab:red",title="differenced with rolling mean over 12 months",ax=ax1)

ax2=plt.subplot(1,2,1)

data.plot(figsize=(12,4),color='tab:red',title="original data",ax=ax2)

plt.show()

# %%
rolling_mean_detrended[:13]
# Out:
#             #Passengers
# Month
# 1949-01-01          NaN
# 1949-02-01          NaN
# 1949-03-01          NaN
# 1949-04-01          NaN
# 1949-05-01          NaN
# 1949-06-01          NaN
# 1949-07-01          NaN
# 1949-08-01          NaN
# 1949-09-01          NaN
# 1949-10-01          NaN
# 1949-11-01          NaN
# 1949-12-01    -8.666667
# 1950-01-01   -11.916667

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decompose_result=seasonal_decompose(rolling_mean_detrended.dropna())

# %%
decompose_result.plot();

# %%
# seasonal differencing--> shift()

# %%
rolling_mean_detrended[:13]
# Out:
#             #Passengers
# Month
# 1949-01-01          NaN
# 1949-02-01          NaN
# 1949-03-01          NaN
# 1949-04-01          NaN
# 1949-05-01          NaN
# 1949-06-01          NaN
# 1949-07-01          NaN
# 1949-08-01          NaN
# 1949-09-01          NaN
# 1949-10-01          NaN
# 1949-11-01          NaN
# 1949-12-01    -8.666667
# 1950-01-01   -11.916667

# %%
rolling_mean_detrended.shift()[:13]
# shift data by 1
# Out:
#             #Passengers
# Month
# 1949-01-01          NaN
# 1949-02-01          NaN
# 1949-03-01          NaN
# 1949-04-01          NaN
# 1949-05-01          NaN
# 1949-06-01          NaN
# 1949-07-01          NaN
# 1949-08-01          NaN
# 1949-09-01          NaN
# 1949-10-01          NaN
# 1949-11-01          NaN
# 1949-12-01          NaN
# 1950-01-01    -8.666667

# %%
rolling_mean_detrended_diff=rolling_mean_detrended-rolling_mean_detrended.shift()

# %%
ax1=plt.subplot(1,2,2)
rolling_mean_detrended.plot(figsize=(12,4),color="tab:red",title="differenced with rolling mean over 12 months",ax=ax1)

ax2=plt.subplot(1,2,1)

data.plot(figsize=(12,4),color='tab:red',title="original data",ax=ax2)

plt.show()

# %%
ax1=plt.subplot(1,2,2)
rolling_mean_detrended_diff.plot(figsize=(12,4),color="tab:red",title="rolling_mean_detrended_diff",ax=ax1)

ax2=plt.subplot(1,2,1)

rolling_mean_detrended.plot(figsize=(12,4),color='tab:red',title="rolling_mean_detrended",ax=ax2)

plt.show()

# %%
rolling_mean_detrended_diff=rolling_mean_detrended_diff.dropna()

# %%
result=adfuller(rolling_mean_detrended_diff['#Passengers'])
pval=result[1]
pval
# Out:
# 0.02277526496785854

# %%
# yes it is stationary

# %%
m=rolling_mean_detrended_diff.rolling(window=12).mean()
s=rolling_mean_detrended_diff.rolling(window=12).std()

# %%
plt.plot(rolling_mean_detrended_diff,color='blue')
plt.plot(m,color='red')
plt.plot(s,color='black')
plt.title("mean and sd")
# Out:
# Text(0.5, 1.0, 'mean and sd')

# %%
# !pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in c:\users\ritik\anaconda3\lib\site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\ritik\anaconda3\lib\site-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\ritik\anaconda3\lib\site-packages (from pmdarima) (3.0.7)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ritik\anaconda3\lib\site-packages (from pmdarima) (1.23.5)
# Requirement already satisfied: pandas>=0.19 in c:\users\ritik\anaconda3\lib\site-packages (from pmdarima) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\ritik\anaconda3\lib\site-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\ritik\anaconda3\lib\site-packages (from pmdarima) (1.10.1)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\ritik\anaconda3\lib\site-packages (from pmdarima) (0.13.5)
# Requirement already satisfied: urllib3 in c:\users\ritik\anaconda3\lib\site-packages (from pmdarima) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\ritik\anaconda3\lib\site-packages (from pmdarima) (67.8.0)
# Requirement already satisfied: packaging>=17.1 in c:\users\ritik\anaconda3\lib\site-packages (from pmdarima) (23.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ritik\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ritik\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ritik\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\ritik\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in c:\users\ritik\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)

# %%
from pmdarima import auto_arima

# %%
order=auto_arima(rolling_mean_detrended_diff['#Passengers'])

# %%
order.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  132
# Model:               SARIMAX(3, 0, 3)   Log Likelihood                -610.892
# Date:                Wed, 03 Jan 2024   AIC                           1235.785
# Time:                        20:23:29   BIC                           1255.964
# Sample:                    01-01-1950   HQIC                          1243.985
#                          - 12-01-1960
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8644      0.162      5.348      0.000       0.548       1.181
# ar.L2          0.2042      0.230      0.889      0.374      -0.246       0.654
# ar.L3         -0.5266      0.140     -3.773      0.000      -0.800      -0.253
# ma.L1         -0.9136      0.128     -7.156      0.000      -1.164      -0.663
# ma.L2         -0.8210      0.168     -4.886      0.000      -1.150      -0.492
# ma.L3          0.7469      0.095      7.853      0.000       0.560       0.933
# sigma2       586.1867     67.804      8.645      0.000     453.294     719.079
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.13   Jarque-Bera (JB):                 2.56
# Prob(Q):                              0.72   Prob(JB):                         0.28
# Heteroskedasticity (H):               6.24   Skew:                             0.28
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
train=rolling_mean_detrended_diff.iloc[:120]['#Passengers'] # 1st 120 rows for training (10 yr)
test=rolling_mean_detrended_diff.iloc[120:]['#Passengers'] # remaining rows after 120 i will take for train

# %%
train
# 10 yr
# Out:
# Month
# 1950-01-01     -3.250000
# 1950-02-01     10.333333
# 1950-03-01     14.250000
# 1950-04-01     -6.500000
# 1950-05-01    -10.333333
#                  ...
# 1959-08-01      6.500000
# 1959-09-01   -100.916667
# 1959-10-01    -60.000000
# 1959-11-01    -49.333333
# 1959-12-01     37.333333
# Name: #Passengers, Length: 120, dtype: float64

# %%
test
# 1 yr
# Out:
# Month
# 1960-01-01      7.250000
# 1960-02-01    -30.083333
# 1960-03-01     26.916667
# 1960-04-01     36.583333
# 1960-05-01      6.666667
# 1960-06-01     57.750000
# 1960-07-01     80.833333
# 1960-08-01    -19.916667
# 1960-09-01   -101.750000
# 1960-10-01    -51.500000
# 1960-11-01    -73.333333
# 1960-12-01     39.750000
# Name: #Passengers, dtype: float64

# %%
model=ARIMA(train,order=(3,0,3)) # ARMA ---> i=0
model_fit=model.fit()
# Out:
# C:\Users\ritik\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritik\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritik\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritik\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ritik\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\ritik\anaconda3\Lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
len(train)
# Out:
# 120

# %%
len(train)+len(test)-1
# Out:
# 131

# %%
rolling_mean_detrended_diff['predict']=model_fit.predict(start=len(train),end=len(train)+len(test)-1)

# %%
rolling_mean_detrended_diff[['#Passengers','predict']].plot()
# Out:
# <Axes: xlabel='Month'>

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model=SARIMAX(train,order=(3,0,3),seasonal_order=(3,0,3,12))
# Out:
# C:\Users\ritik\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritik\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model=model.fit()
# Out:
# C:\Users\ritik\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ritik\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\ritik\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# C:\Users\ritik\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\ritik\anaconda3\Lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
rolling_mean_detrended_diff['predict']=model.predict(start=len(train),end=len(train)+len(test)-1)

# %%
rolling_mean_detrended_diff[['#Passengers','predict']].plot()
# Out:
# <Axes: xlabel='Month'>

# %%
forecast=model.forecast(steps=60)
rolling_mean_detrended_diff.plot()
forecast.plot()
# Out:
# <Axes: xlabel='Month'>
